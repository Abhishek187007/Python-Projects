# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data={
    'season':[2023,2022,2021,2020,2019,2018,2017],
    'Winners':['BB','HYD','HS','DD','HS','JP','PP'],
    'Runners':['PP','TT','BB','UM','UM','BB','PU'],
    'CityW':['BENGALURU BULLS','TELUGU TAITANS','HARYANA STEELERS','DABANG DELHI','HARYANA STEELERS','JAIPUR PINK PANTHERS','PUNERI PALTAN'],
    'CityR':['PUNERI PALTAN','TAMIL THAILAVAS','BENGALURU BULLS','UMUMBA','UMUMBA','BENGALURU BULLS','PUNERI PALTAN'],
    'Player Of The Season':['Ajay Thakur','Pardeep Narwal','Shardluoi','Aslam Inamdar','Shardluoi','Pardeep Narwal','Rahul Sethpal'],
    'Trophy Won':[2,4,1,3,2,4,1,],
    'Points':[56,34,89,56,99,67,45],
}
df=pd.DataFrame(data)
df
# Out:
#    season Winners Runners                 CityW            CityR  \
# 0    2023      BB      PP       BENGALURU BULLS    PUNERI PALTAN
# 1    2022     HYD      TT        TELUGU TAITANS  TAMIL THAILAVAS
# 2    2021      HS      BB      HARYANA STEELERS  BENGALURU BULLS
# 3    2020      DD      UM          DABANG DELHI           UMUMBA
# 4    2019      HS      UM      HARYANA STEELERS           UMUMBA
# 5    2018      JP      BB  JAIPUR PINK PANTHERS  BENGALURU BULLS
# 6    2017      PP      PU         PUNERI PALTAN    PUNERI PALTAN
#
#   Player Of The Season  Trophy Won  Points
# 0          Ajay Thakur           2      56
# 1       Pardeep Narwal           4      34
# 2            Shardluoi           1      89
# 3        Aslam Inamdar           3      56
# 4            Shardluoi           2      99
# 5       Pardeep Narwal           4      67
# 6        Rahul Sethpal           1      45

# %%
print(df.head())
print(df.info())
# Out:
#    season Winners Runners             CityW            CityR  \
# 0    2023      BB      PP   BENGALURU BULLS    PUNERI PALTAN
# 1    2022     HYD      TT    TELUGU TAITANS  TAMIL THAILAVAS
# 2    2021      HS      BB  HARYANA STEELERS  BENGALURU BULLS
# 3    2020      DD      UM      DABANG DELHI           UMUMBA
# 4    2019      HS      UM  HARYANA STEELERS           UMUMBA
#
#   Player Of The Season  Trophy Won  Points
# 0          Ajay Thakur           2      56
# 1       Pardeep Narwal           4      34
# 2            Shardluoi           1      89
# 3        Aslam Inamdar           3      56
# 4            Shardluoi           2      99
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   season                7 non-null      int64
#  1   Winners               7 non-null      object
# ...

# %%
Team_Wins=df['Winners'].value_counts()
print("\nTeam_Wins\n",Team_Wins)
# Out:
# Team_Wins
#  Winners
# HS     2
# BB     1
# HYD    1
# DD     1
# JP     1
# PP     1
# Name: count, dtype: int64

# %%
PM_counts=df['Player Of The Season'].value_counts()
print("\nPlayer Of The Season\n",PM_counts)
# Out:
# Player Of The Season
#  Player Of The Season
# Pardeep Narwal    2
# Shardluoi         2
# Ajay Thakur       1
# Aslam Inamdar     1
# Rahul Sethpal     1
# Name: count, dtype: int64

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
average_points=df['Points'].mean()
print("\nAverage Points\n",average_points)
# Out:
# Average Points
#  63.714285714285715

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='season',y='Points',data=df)
plt.title('Season vs Points')
plt.xlabel('Season')
plt.ylabel('Points')
plt.show()
